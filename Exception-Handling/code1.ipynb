# %%
l = [1,2,3]
l.upper()
#the error message is called stacktrace
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 l = [1,2,3]
# ----> 2 l.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
with open('file.txt', 'w') as f:
    f.write('hello world')

# %%
with open("file1.txt") as f:
    print(f.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 with open("file1.txt") as f:
#       2     print(f.read())
#
# FileNotFoundError: [Errno 2] No such file or directory: 'file1.txt'

# %%
try:
    with open("file1.txt") as f:
      print(f.read())
except:
    print('file is not found / incorrect file name')
# Out:
# file is not found / incorrect file name

# %%
def fun1():
    return "hello"
fun1()
# Out:
# 'hello'

# %%
def fun2():
    print("hello")
x = fun2() # this will return None because fun2() does not have a return statement
print(x)
# Out:
# hello
# None

# %%
try:
    with open("file.txt") as f:
      print(f.read())
      print(m)
except NameError:
   print("variable not found")
except FileNotFoundError:
   print("file not found")
except Exception as e:
   print(e)
   print(e.with_traceback)
# Out:
# hello world
# variable not found

# %%
#else execute when try runs 
# its is same but readibilty is good 
try:
    f =  open('file.txt','r')      
except FileNotFoundError:   
    print("file not found")

else:
    print(f.read())
# Out:
# hello world

# %%
#finally
try:
    f =  open('file.txt','r')      
except FileNotFoundError:   
    print("file not found")

else:
    print(f.read())

#in finally we close important things for security like close blutooth
finally:
    print("ye toh run hoga hi chahe run ho code ya nhi")
# Out:
# hello world
# ye toh run hoga hi chahe run ho code ya nhi

# %%
#raise
#except -> catch 
#raise -> throw
raise RuntimeError("just i am cheking")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[18], line 2
#       1 #raise
# ----> 2 raise RuntimeError("just i am cheking")
#
# RuntimeError: just i am cheking

# %%
class SecurityError(Exception):
    # pass
    def __init__(self,message):
        print(message)
    def logout(self):
        print("logout")


class google:
    def __init__(self,name,email,password,device):
    
        self.name = name
        self.email = email
        self.password = password
        self.device = device
    def login(self,email,password,device):
        if device != self.device:
            raise SecurityError("another device is trying to login")
        if email== self.email and password == self.password:
            print("welcome back")
        else:
            print("login failed")

object = google('kartikey','kartikey@gmail.com','password123','device1')

try:
    object.login('kartikey@gmail.com','password123','device2')
except SecurityError as e:
    print(e)
# Out:
# another device is trying to login
# another device is trying to login
